# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('U.S. National Home Price Index.csv')
df.shape
# Out:
# (241, 13)

# %%
df.head()
# Out:
#          DATE  Consumer price index urban  Unemployment rate  \
# 0  01-06-2003                       183.1                6.3
# 1  01-07-2003                       183.7                6.2
# 2  01-08-2003                       184.5                6.1
# 3  01-09-2003                       185.1                6.1
# 4  01-10-2003                       184.9                6.0
#
#    Employment rate 15-64 US  Labour force participation rate  \
# 0                 71.214996                             66.5
# 1                 70.988735                             66.2
# 2                 71.002070                             66.1
# 3                 70.918990                             66.1
# 4                 71.056346                             66.1
#
#    Labour force participation rate Men  Labour force participation rate Women  \
# 0                                 73.6                                   59.9
# 1                                 73.4                                   59.5
# 2                                 73.3                                   59.5
# 3                                 73.6                                   59.1
# 4                                 73.4                                   59.3
#
#    Federal funds effective rate  Job Openings Total Nonfarm  \
# 0                          1.22                        3390
# 1                          1.01                        2981
# 2                          1.03                        3190
# 3                          1.01                        3091
# 4                          1.01                        3305
#
#    Crude Oil Import Price   \
# 0                     98.2
# 1                    104.3
# 2                    105.4
# 3                     98.5
# 4                    100.1
#
#    Consumer Price Index Tuition, School Fees, and Childcare in U.S. City Average  \
# 0                                              384.3
# 1                                              386.4
# 2                                              391.2
# 3                                              393.7
# 4                                              395.4
#
#    Mortgage Average in the United States  National home price index
# 0                                 5.2300                    132.649
# 1                                 5.6325                    133.777
# 2                                 6.2640                    134.968
# 3                                 6.1475                    136.294
# 4                                 5.9520                    137.532

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 13 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   DATE                                                                           241 non-null    object
#  1   Consumer price index urban                                                     241 non-null    float64
#  2   Unemployment rate                                                              241 non-null    float64
#  3   Employment rate 15-64 US                                                       241 non-null    float64
#  4   Labour force participation rate                                                241 non-null    float64
#  5   Labour force participation rate Men                                            241 non-null    float64
#  6   Labour force participation rate Women                                          241 non-null    float64
#  7   Federal funds effective rate                                                   241 non-null    float64
#  8   Job Openings Total Nonfarm                                                     241 non-null    int64
#  9   Crude Oil Import Price                                                         241 non-null    float64
#  10  Consumer Price Index Tuition, School Fees, and Childcare in U.S. City Average  241 non-null    float64
#  11  Mortgage Average in the United States                                          241 non-null    float64
#  12  National home price index                                                      241 non-null    float64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 24.6+ KB

# %%
df.describe()
# Out:
#        Consumer price index urban  Unemployment rate  \
# count                  241.000000         241.000000
# mean                   232.794158           5.951867
# std                     28.795774           2.066480
# min                    183.100000           3.400000
# 25%                    212.705000           4.400000
# 50%                    232.900000           5.400000
# 75%                    251.018000           7.300000
# max                    303.841000          14.700000
#
#        Employment rate 15-64 US  Labour force participation rate  \
# count                241.000000                       241.000000
# mean                  69.517691                        63.938589
# std                    2.066788                         1.590167
# min                   60.203690                        60.100000
# 25%                   67.700450                        62.800000
# 50%                   70.087612                        63.300000
# 75%                   71.279227                        65.900000
# max                   72.325534                        66.500000
#
#        Labour force participation rate Men  \
# count                           241.000000
# mean                             70.438174
# std                               2.061178
# min                              66.100000
# 25%                              69.000000
# 50%                              69.800000
# 75%                              72.900000
# max                              73.800000
#
#        Labour force participation rate Women  Federal funds effective rate  \
# count                             241.000000                    241.000000
# mean                               57.843568                      1.388548
# std                                 1.186192                      1.665332
# min                                54.600000                      0.050000
# 25%                                56.900000                      0.120000
# 50%                                57.600000                      0.400000
# 75%                                59.200000                      2.190000
# max                                59.900000                      5.260000
#
#        Job Openings Total Nonfarm  Crude Oil Import Price   \
# count                  241.000000               241.000000
# mean                  5405.614108               261.822822
# std                   2344.509891                96.034329
# min                   2232.000000                86.700000
# 25%                   3793.000000               188.800000
# 50%                   4652.000000               246.500000
# 75%                   6512.000000               341.000000
# max                  12027.000000               491.000000
#
#        Consumer Price Index Tuition, School Fees, and Childcare in U.S. City Average  \
# count                                         241.000000
# mean                                          629.122452
# std                                           129.034576
# min                                           384.300000
# 25%                                           520.480000
# 50%                                           642.074000
# 75%                                           738.409000
# max                                           835.686000
#
#        Mortgage Average in the United States  National home price index
# count                             241.000000                 241.000000
# mean                                4.704355                 184.676498
# std                                 1.131350                  44.512048
# min                                 2.684000                 132.649000
# 25%                                 3.802500                 149.850000
# 50%                                 4.457500                 174.443000
# 75%                                 5.774000                 202.243000
# max                                 6.900000                 304.817000

# %%
df.nunique()
# Out:
# DATE                                                                             241
# Consumer price index urban                                                       236
# Unemployment rate                                                                 64
# Employment rate 15-64 US                                                         241
# Labour force participation rate                                                   52
# Labour force participation rate Men                                               64
# Labour force participation rate Women                                             40
# Federal funds effective rate                                                     114
# Job Openings Total Nonfarm                                                       239
# Crude Oil Import Price                                                           233
# Consumer Price Index Tuition, School Fees, and Childcare in U.S. City Average    241
# Mortgage Average in the United States                                            230
# National home price index                                                        241
# dtype: int64

# %%
df.isnull().sum()
# Out:
# DATE                                                                             0
# Consumer price index urban                                                       0
# Unemployment rate                                                                0
# Employment rate 15-64 US                                                         0
# Labour force participation rate                                                  0
# Labour force participation rate Men                                              0
# Labour force participation rate Women                                            0
# Federal funds effective rate                                                     0
# Job Openings Total Nonfarm                                                       0
# Crude Oil Import Price                                                           0
# Consumer Price Index Tuition, School Fees, and Childcare in U.S. City Average    0
# Mortgage Average in the United States                                            0
# National home price index                                                        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

x =  df['DATE']
Y = df['Employment rate 15-64 US']

plt.plot(x, Y)
plt.show()

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %%
df = df.drop(['DATE'], axis = 1)

# %%
sns.boxplot(data = df)
# Out:
# <AxesSubplot:>

# %%
X = df.iloc[ :,0:-1]
y = df['National home price index']

# %%
X
# Out:
#      Consumer price index urban  Unemployment rate  Employment rate 15-64 US  \
# 0                       183.100                6.3                 71.214996
# 1                       183.700                6.2                 70.988735
# 2                       184.500                6.1                 71.002070
# 3                       185.100                6.1                 70.918990
# 4                       184.900                6.0                 71.056346
# ..                          ...                ...                       ...
# 236                     301.648                3.6                 71.735610
# 237                     301.808                3.5                 71.896826
# 238                     302.918                3.4                 71.985899
# 239                     303.294                3.7                 71.944552
# 240                     303.841                3.6                 72.011926
#
#      Labour force participation rate  Labour force participation rate Men  \
# 0                               66.5                                 73.6
# 1                               66.2                                 73.4
# 2                               66.1                                 73.3
# 3                               66.1                                 73.6
# 4                               66.1                                 73.4
# ..                               ...                                  ...
# 236                             62.5                                 68.0
# 237                             62.6                                 68.4
# 238                             62.6                                 68.1
# 239                             62.6                                 68.1
# 240                             62.6                                 68.1
#
#      Labour force participation rate Women  Federal funds effective rate  \
# 0                                     59.9                          1.22
# 1                                     59.5                          1.01
# 2                                     59.5                          1.03
# 3                                     59.1                          1.01
# 4                                     59.3                          1.01
# ..                                     ...                           ...
# 236                                   57.2                          4.57
# 237                                   57.1                          4.65
# 238                                   57.3                          4.83
# 239                                   57.3                          5.06
# 240                                   57.3                          5.08
#
#      Job Openings Total Nonfarm  Crude Oil Import Price   \
# 0                          3390                     98.2
# 1                          2981                    104.3
# 2                          3190                    105.4
# 3                          3091                     98.5
# 4                          3305                    100.1
# ..                          ...                      ...
# 236                        9974                    289.4
# 237                        9745                    284.6
# 238                       10320                    307.0
# 239                        9616                    296.9
# 240                        9165                    299.0
#
#      Consumer Price Index Tuition, School Fees, and Childcare in U.S. City Average  \
# 0                                              384.300
# 1                                              386.400
# 2                                              391.200
# 3                                              393.700
# 4                                              395.400
# ..                                                 ...
# 236                                            826.723
# 237                                            831.488
# 238                                            833.701
# 239                                            834.279
# 240                                            835.686
#
#      Mortgage Average in the United States
# 0                                   5.2300
# 1                                   5.6325
# 2                                   6.2640
# 3                                   6.1475
# 4                                   5.9520
# ..                                     ...
# 236                                 6.2575
# 237                                 6.5440
# 238                                 6.3425
# 239                                 6.4250
# 240                                 6.7140
#
# [241 rows x 11 columns]

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
df = SS.fit_transform(df)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 5)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (168, 11)
# (73, 11)
# (168,)
# (73,)

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
print(lr.score(X_train, y_train))
print(lr.score(X_test, y_test))
# Out:
# 0.9756770388008886
# 0.9761454616003284

# %%
gbr = GradientBoostingRegressor(n_estimators = 10, learning_rate = 0.1, random_state =42)
gbr.fit(X_train,y_train)
print(gbr.score(X_train,y_train))
print(gbr.score(X_test,y_test))
# Out:
# 0.8674747965365652
# 0.864578270359507

# %%
final_model = lr
y_pred = final_model.predict(X_test)

# %%
from sklearn import metrics
print(metrics.mean_squared_error(y_test,y_pred))
print(metrics.mean_absolute_error(y_test, y_pred))
print(metrics.r2_score(y_test,y_pred))
# Out:
# 52.20179826674678
# 5.408775038544128
# 0.9761454616003284
